# %% [markdown]
# **[Coffee Bean Dataset](https://www.kaggle.com/datasets/gpiosenka/coffee-bean-dataset-resized-224-x-224?select=train)**

# %%
import numpy as np
import pandas as pd

import io
import os


from PIL import Image
from glob import glob
import itertools

import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt
import seaborn as sns


import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, Flatten,Conv2D, MaxPooling2D,BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping , ModelCheckpoint

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %%
train_dir = os.path.join( 'Coffee Bean Dataset/train')
test_dir = os.path.join('Coffee Bean Dataset/test')

# %%
df=pd.read_csv("Coffee Bean Dataset/Coffee Bean.csv")

# %%
df.head()
# Out:
#    class index                  filepaths labels data set
# 0            0    train/Dark/dark (1).png   Dark    train
# 1            0   train/Dark/dark (10).png   Dark    train
# 2            0  train/Dark/dark (100).png   Dark    train
# 3            0  train/Dark/dark (101).png   Dark    train
# 4            0  train/Dark/dark (102).png   Dark    train

# %%
df.labels.value_counts()
# Out:
# Dark      400
# Green     400
# Light     400
# Medium    400
# Name: labels, dtype: int64

# %%
df["data set"].value_counts()
# Out:
# train    1200
# test      400
# Name: data set, dtype: int64

# %% [markdown]
# **Data pre-processing and data augmentation**
#
# In order to make the most of our few training examples, we will "augment" them via a number of random transformations, so that our model would never see twice the exact same picture. This helps prevent overfitting and helps the model generalize better.
#
# In Keras this can be done via the keras.preprocessing.image.ImageDataGenerator class. This class allows you to:
#
# - configure random transformations and normalization operations to be done on your image data during training
# - instantiate generators of augmented image batches (and their labels) via .flow(data, labels) or .flow_from_directory(directory). These generators can then be used with the Keras model methods that accept data generators as inputs, fit_generator, evaluate_generator and predict_generator.

# %%
# Use the Image Data Generator to import the images from the dataset
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale = 1./255)

# %% [markdown]
# These are just a few of the options available :-
#
# - **rotation_range** is a value in degrees (0-180), a range within which to randomly rotate pictures
# - **width_shift** and height_shift are ranges (as a fraction of total width or height) within which to randomly translate pictures vertically or horizontally
# - **rescale** is a value by which we will multiply the data before any other processing. Our original images consist in RGB coefficients in the 0-255, but such values would be too high for our models to process (given a typical learning rate), so we target values between 0 and 1 instead by scaling with a 1/255. factor.
# - **shear_range** is for randomly applying shearing transformations
# - **zoom_range** is for randomly zooming inside pictures
# - **horizontal_flip** is for randomly flipping half of the images horizontally --relevant when there are no assumptions of horizontal assymetry (e.g. real-world pictures).
# - **fill_mode** is the strategy used for filling in newly created pixels, which can appear after a rotation or a width/height shift.

# %%
training_set = train_datagen.flow_from_directory(train_dir,
                                                 target_size = (224, 224),
                                                 batch_size = 16,
                                                 class_mode = 'categorical')

test_set = test_datagen.flow_from_directory(test_dir,
                                            target_size = (224, 224),
                                            batch_size = 16,
                                            class_mode = 'categorical')
# Out:
# Found 1200 images belonging to 4 classes.
# Found 400 images belonging to 4 classes.

# %%
folders = glob('Coffee Bean Dataset/train/*')
folders
# Out:
# ['Coffee Bean Dataset/train\\Dark',
#  'Coffee Bean Dataset/train\\Green',
#  'Coffee Bean Dataset/train\\Light',
#  'Coffee Bean Dataset/train\\Medium']

# %% [markdown]
# ## Model creation

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
model = Sequential()

# Convolutional layers
model.add(Conv2D(filters=96, kernel_size=(11, 11), strides=(4, 4), padding='valid', input_shape=(224, 224, 3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2),padding="valid"))

model.add(Conv2D(filters=256,kernel_size=(5,5),strides=(1,1),padding="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2),padding="valid"))

model.add(Conv2D(filters=384,kernel_size=(3,3),strides=(1,1),padding="same"))
model.add(Activation("relu"))

model.add(Conv2D(filters=384,kernel_size=(3,3),strides=(1,1),padding="same"))
model.add(Activation("relu"))

model.add(Conv2D(filters=256,kernel_size=(3,3),strides=(1,1),padding="same"))
model.add(Activation("relu"))

model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2),padding="valid"))

# Fully connected layers
model.add(Flatten())
model.add(Dense(4096,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4096,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4,activation='softmax'))

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer=tf.optimizers.SGD(lr=0.001),
    metrics=['accuracy']    
)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 54, 54, 96)        34944
#
#  activation (Activation)     (None, 54, 54, 96)        0
#
#  max_pooling2d (MaxPooling2D  (None, 26, 26, 96)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 26, 26, 256)       614656
#
#  activation_1 (Activation)   (None, 26, 26, 256)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 256)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 384)       885120
#
#  activation_2 (Activation)   (None, 12, 12, 384)       0
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 384)       1327488
#
#  activation_3 (Activation)   (None, 12, 12, 384)       0
#
#  conv2d_4 (Conv2D)           (None, 12, 12, 256)       884992
#
#  activation_4 (Activation)   (None, 12, 12, 256)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 5, 5, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 6400)              0
#
#  dense (Dense)               (None, 4096)              26218496
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 4)                 16388
#
# =================================================================
# Total params: 46,763,396
# Trainable params: 46,763,396
# Non-trainable params: 0
# _________________________________________________________________
# C:\Users\HP\Anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
# fit the model
epochs = 50
history = model.fit(training_set, validation_data=test_set,epochs=epochs,
            steps_per_epoch=len(training_set),
            validation_steps=len(test_set), 
            verbose=1,)
# Out:
# Epoch 1/50
# 75/75 [==============================] - 60s 667ms/step - loss: 1.3863 - accuracy: 0.2433 - val_loss: 1.3840 - val_accuracy: 0.2500
# Epoch 2/50
# 75/75 [==============================] - 44s 589ms/step - loss: 1.3836 - accuracy: 0.2675 - val_loss: 1.3824 - val_accuracy: 0.2500
# Epoch 3/50
# 75/75 [==============================] - 17s 222ms/step - loss: 1.3832 - accuracy: 0.2667 - val_loss: 1.3805 - val_accuracy: 0.2500
# Epoch 4/50
# 75/75 [==============================] - 16s 215ms/step - loss: 1.3819 - accuracy: 0.2550 - val_loss: 1.3791 - val_accuracy: 0.2500
# Epoch 5/50
# 75/75 [==============================] - 16s 210ms/step - loss: 1.3816 - accuracy: 0.2617 - val_loss: 1.3777 - val_accuracy: 0.2925
# Epoch 6/50
# 75/75 [==============================] - 16s 219ms/step - loss: 1.3783 - accuracy: 0.2708 - val_loss: 1.3760 - val_accuracy: 0.2625
# Epoch 7/50
# 75/75 [==============================] - 16s 207ms/step - loss: 1.3783 - accuracy: 0.2700 - val_loss: 1.3740 - val_accuracy: 0.2825
# Epoch 8/50
# 75/75 [==============================] - 16s 209ms/step - loss: 1.3785 - accuracy: 0.2750 - val_loss: 1.3716 - val_accuracy: 0.2550
# Epoch 9/50
# 75/75 [==============================] - 16s 211ms/step - loss: 1.3771 - accuracy: 0.2833 - val_loss: 1.3695 - val_accuracy: 0.2500
# Epoch 10/50
# 75/75 [==============================] - 16s 208ms/step - loss: 1.3729 - accuracy: 0.2892 - val_loss: 1.3663 - val_accuracy: 0.2500
# Epoch 11/50
# 75/75 [==============================] - 16s 214ms/step - loss: 1.3746 - accuracy: 0.2792 - val_loss: 1.3632 - val_accuracy: 0.2525
# Epoch 12/50
# 75/75 [==============================] - 16s 213ms/step - loss: 1.3715 - accuracy: 0.2975 - val_loss: 1.3594 - val_accuracy: 0.2600
# Epoch 13/50
# 75/75 [==============================] - 16s 209ms/step - loss: 1.3670 - accuracy: 0.3125 - val_loss: 1.3550 - val_accuracy: 0.2525
# Epoch 14/50
# 75/75 [==============================] - 16s 208ms/step - loss: 1.3666 - accuracy: 0.2883 - val_loss: 1.3496 - val_accuracy: 0.2675
# Epoch 15/50
# 75/75 [==============================] - 16s 213ms/step - loss: 1.3557 - accuracy: 0.3392 - val_loss: 1.3434 - val_accuracy: 0.2525
# Epoch 16/50
# 75/75 [==============================] - 16s 214ms/step - loss: 1.3537 - accuracy: 0.3550 - val_loss: 1.3327 - val_accuracy: 0.3525
# Epoch 17/50
# 75/75 [==============================] - 16s 213ms/step - loss: 1.3496 - accuracy: 0.3600 - val_loss: 1.3215 - val_accuracy: 0.4950
# Epoch 18/50
# 75/75 [==============================] - 16s 217ms/step - loss: 1.3423 - accuracy: 0.3667 - val_loss: 1.3066 - val_accuracy: 0.4500
# Epoch 19/50
# 75/75 [==============================] - 16s 211ms/step - loss: 1.3250 - accuracy: 0.3958 - val_loss: 1.2846 - val_accuracy: 0.5325
# Epoch 20/50
# 75/75 [==============================] - 16s 210ms/step - loss: 1.3192 - accuracy: 0.3917 - val_loss: 1.2620 - val_accuracy: 0.5000
# Epoch 21/50
# 75/75 [==============================] - 16s 211ms/step - loss: 1.2951 - accuracy: 0.4192 - val_loss: 1.2417 - val_accuracy: 0.3775
# Epoch 22/50
# 75/75 [==============================] - 17s 226ms/step - loss: 1.2594 - accuracy: 0.4558 - val_loss: 1.2138 - val_accuracy: 0.3175
# Epoch 23/50
# 75/75 [==============================] - 17s 221ms/step - loss: 1.2276 - accuracy: 0.4575 - val_loss: 1.0951 - val_accuracy: 0.5850
# Epoch 24/50
# 75/75 [==============================] - 16s 215ms/step - loss: 1.1607 - accuracy: 0.4708 - val_loss: 1.1075 - val_accuracy: 0.4075
# Epoch 25/50
# 75/75 [==============================] - 16s 213ms/step - loss: 1.1019 - accuracy: 0.4642 - val_loss: 0.9307 - val_accuracy: 0.5250
# Epoch 26/50
# 75/75 [==============================] - 16s 217ms/step - loss: 1.0525 - accuracy: 0.4950 - val_loss: 0.8645 - val_accuracy: 0.6200
# Epoch 27/50
# 75/75 [==============================] - 16s 214ms/step - loss: 1.0069 - accuracy: 0.5017 - val_loss: 0.8052 - val_accuracy: 0.6150
# Epoch 28/50
# 75/75 [==============================] - 16s 217ms/step - loss: 0.9584 - accuracy: 0.5300 - val_loss: 0.7732 - val_accuracy: 0.6375
# Epoch 29/50
# 75/75 [==============================] - 17s 221ms/step - loss: 0.9161 - accuracy: 0.5517 - val_loss: 0.7276 - val_accuracy: 0.7125
# Epoch 30/50
# 75/75 [==============================] - 16s 214ms/step - loss: 0.9018 - accuracy: 0.5450 - val_loss: 0.7004 - val_accuracy: 0.7500
# Epoch 31/50
# 75/75 [==============================] - 16s 216ms/step - loss: 0.8706 - accuracy: 0.5708 - val_loss: 0.6925 - val_accuracy: 0.7550
# Epoch 32/50
# 75/75 [==============================] - 16s 214ms/step - loss: 0.8661 - accuracy: 0.5550 - val_loss: 0.9119 - val_accuracy: 0.4300
# Epoch 33/50
# 75/75 [==============================] - 17s 222ms/step - loss: 0.8433 - accuracy: 0.5750 - val_loss: 0.9034 - val_accuracy: 0.4500
# Epoch 34/50
# 75/75 [==============================] - 15s 202ms/step - loss: 0.8257 - accuracy: 0.5983 - val_loss: 0.6967 - val_accuracy: 0.6450
# Epoch 35/50
# 75/75 [==============================] - 15s 199ms/step - loss: 0.7963 - accuracy: 0.5867 - val_loss: 0.6389 - val_accuracy: 0.7250
# Epoch 36/50
# 75/75 [==============================] - 15s 198ms/step - loss: 0.8084 - accuracy: 0.5950 - val_loss: 0.9203 - val_accuracy: 0.4500
# Epoch 37/50
# 75/75 [==============================] - 15s 200ms/step - loss: 0.7588 - accuracy: 0.6108 - val_loss: 0.6109 - val_accuracy: 0.7325
# Epoch 38/50
# 75/75 [==============================] - 15s 202ms/step - loss: 0.7787 - accuracy: 0.6242 - val_loss: 0.8263 - val_accuracy: 0.5350
# Epoch 39/50
# 75/75 [==============================] - 15s 200ms/step - loss: 0.7693 - accuracy: 0.5917 - val_loss: 0.6036 - val_accuracy: 0.7575
# Epoch 40/50
# 75/75 [==============================] - 15s 198ms/step - loss: 0.7250 - accuracy: 0.6375 - val_loss: 0.5919 - val_accuracy: 0.7250
# Epoch 41/50
# 75/75 [==============================] - 15s 199ms/step - loss: 0.7280 - accuracy: 0.6242 - val_loss: 1.0518 - val_accuracy: 0.5025
# Epoch 42/50
# 75/75 [==============================] - 15s 199ms/step - loss: 0.7160 - accuracy: 0.6425 - val_loss: 0.5269 - val_accuracy: 0.8150
# Epoch 43/50
# 75/75 [==============================] - 15s 198ms/step - loss: 0.7059 - accuracy: 0.6717 - val_loss: 0.6091 - val_accuracy: 0.6975
# Epoch 44/50
# 75/75 [==============================] - 15s 199ms/step - loss: 0.6915 - accuracy: 0.6667 - val_loss: 0.5809 - val_accuracy: 0.7400
# Epoch 45/50
# 75/75 [==============================] - 15s 199ms/step - loss: 0.6637 - accuracy: 0.6750 - val_loss: 0.4978 - val_accuracy: 0.8450
# Epoch 46/50
# 75/75 [==============================] - 15s 199ms/step - loss: 0.6102 - accuracy: 0.7317 - val_loss: 0.4330 - val_accuracy: 0.8900
# Epoch 47/50
# 75/75 [==============================] - 15s 197ms/step - loss: 0.6116 - accuracy: 0.7500 - val_loss: 0.3922 - val_accuracy: 0.9150
# Epoch 48/50
# 75/75 [==============================] - 15s 199ms/step - loss: 0.5423 - accuracy: 0.7842 - val_loss: 0.3264 - val_accuracy: 0.9175
# Epoch 49/50
# 75/75 [==============================] - 15s 201ms/step - loss: 0.5217 - accuracy: 0.7908 - val_loss: 0.3718 - val_accuracy: 0.8900
# Epoch 50/50
# 75/75 [==============================] - 15s 199ms/step - loss: 0.4807 - accuracy: 0.8167 - val_loss: 0.2751 - val_accuracy: 0.9175

# %%
scores = model.evaluate(test_set)
# Out:
# 25/25 [==============================] - 1s 35ms/step - loss: 0.2751 - accuracy: 0.9175

# %%
print("test loss",scores[0])
print("test accuracy",scores[1])
# Out:
# test loss 0.2750852704048157
# test accuracy 0.9175000190734863

# %%
plt.plot(history.history['loss'], label='Loss (training data)')
plt.plot(history.history['val_loss'], label='Loss (validation data)')
plt.title('Loss for Training')
plt.ylabel('Loss')
plt.xlabel('No. epoch')
plt.legend(['train', 'validation'], loc="upper left")
plt.show()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

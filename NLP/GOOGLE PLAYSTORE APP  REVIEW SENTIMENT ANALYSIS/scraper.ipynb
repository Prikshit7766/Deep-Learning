# %%
pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Using cached google_play_scraper-1.2.2-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from google_play_scraper import Sort, reviews_all, reviews, app
import pandas as pd
import numpy as np

# %%
result = reviews_all(
    'com.twitter.android',
    sleep_milliseconds=0, # defaults to 0
    lang='id',            # defaults to 'en'
    country='id',         # defaults to 'us'
    sort=Sort.NEWEST,     # defaults to Sort.MOST_RELEVANT , you can use Sort.NEWEST to get newst reviews
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 result = reviews_all(
#       2     'com.twitter.android',
#       3     sleep_milliseconds=0, # defaults to 0
#       4     lang='id',            # defaults to 'en'
#       5     country='id',         # defaults to 'us'
#       6     sort=Sort.NEWEST,     # defaults to Sort.MOST_RELEVANT , you can use Sort.NEWEST to get newst reviews
#       7 )
#
# File ~\anaconda3\lib\site-packages\google_play_scraper\features\reviews.py:129, in reviews_all(app_id, sleep_milliseconds, **kwargs)
#     126 result = []
#     128 while True:
# --> 129     _result, continuation_token = reviews(
#     130         app_id,
#     131         count=MAX_COUNT_EACH_FETCH,
#     132         continuation_token=continuation_token,
#     133         **kwargs
#     134     )
#     136     result += _result
#     138     if continuation_token.token is None:
#
# File ~\anaconda3\lib\site-packages\google_play_scraper\features\reviews.py:93, in reviews(app_id, lang, country, sort, count, filter_score_with, continuation_token)
#      90     _fetch_count = MAX_COUNT_EACH_FETCH
#      92 try:
# ---> 93     review_items, token = _fetch_review_items(
#      94         url, app_id, sort, _fetch_count, filter_score_with, token
#      95     )
#      96 except (TypeError, IndexError):
#      97     token = None
#
# File ~\anaconda3\lib\site-packages\google_play_scraper\features\reviews.py:36, in _fetch_review_items(url, app_id, sort, count, filter_score_with, pagination_token)
#      28 def _fetch_review_items(
#      29     url: str,
#      30     app_id: str,
#    (...)
#      34     pagination_token: Optional[str],
#      35 ):
# ---> 36     dom = post(
#      37         url,
#      38         Formats.Reviews.build_body(
#      39             app_id,
#      40             sort,
#      41             count,
#      42             "null" if filter_score_with is None else filter_score_with,
#      43             pagination_token,
#      44         ),
#      45         {"content-type": "application/x-www-form-urlencoded"},
#      46     )
#      48     match = json.loads(Regex.REVIEWS.findall(dom)[0])
#      50     return json.loads(match[0][2])[0], json.loads(match[0][2])[-1][-1]
#
# File ~\anaconda3\lib\site-packages\google_play_scraper\utils\request.py:24, in post(url, data, headers)
#      23 def post(url: str, data: Union[str, bytes], headers: dict) -> str:
# ---> 24     return _urlopen(Request(url, data=data, headers=headers))
#
# File ~\anaconda3\lib\site-packages\google_play_scraper\utils\request.py:11, in _urlopen(obj)
#       9 def _urlopen(obj):
#      10     try:
# ---> 11         resp = urlopen(obj)
#      12     except HTTPError as e:
#      13         if e.code == 404:
#
# File ~\anaconda3\lib\urllib\request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File ~\anaconda3\lib\urllib\request.py:517, in OpenerDirector.open(self, fullurl, data, timeout)
#     514     req = meth(req)
#     516 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517 response = self._open(req, data)
#     519 # post-process response
#     520 meth_name = protocol+"_response"
#
# File ~\anaconda3\lib\urllib\request.py:534, in OpenerDirector._open(self, req, data)
#     531     return result
#     533 protocol = req.type
# --> 534 result = self._call_chain(self.handle_open, protocol, protocol +
#     535                           '_open', req)
#     536 if result:
#     537     return result
#
# File ~\anaconda3\lib\urllib\request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File ~\anaconda3\lib\urllib\request.py:1389, in HTTPSHandler.https_open(self, req)
#    1388 def https_open(self, req):
# -> 1389     return self.do_open(http.client.HTTPSConnection, req,
#    1390         context=self._context, check_hostname=self._check_hostname)
#
# File ~\anaconda3\lib\urllib\request.py:1350, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1348     except OSError as err: # timeout error
#    1349         raise URLError(err)
# -> 1350     r = h.getresponse()
#    1351 except:
#    1352     h.close()
#
# File ~\anaconda3\lib\http\client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File ~\anaconda3\lib\http\client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File ~\anaconda3\lib\http\client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File ~\anaconda3\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~\anaconda3\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
result, continuation_token = reviews(
    'com.facebook.katana',
    lang='en',                # defaults to 'en'
    country='id',             # defaults to 'us'
    sort=Sort.MOST_RELEVANT,  # defaults to Sort.MOST_RELEVANT you can use Sort.NEWEST to get newst reviews
    count=1500,               # defaults to 100
    filter_score_with=None    # defaults to None(means all score) Use 1 or 2 or 3 or 4 or 5 to select certain score
)

# %%
scrapeddata = pd.DataFrame(np.array(result),columns=['review'])

scrapeddata = scrapeddata.join(pd.DataFrame(scrapeddata.pop('review').tolist()))

scrapeddata.head()
# Out:
#                                reviewId          userName  \
# 0  61abdfa5-02d3-4ab6-b5d1-1dcb79164b7f   Ilham Zainulhaq
# 1  6588fb7b-e1ed-4715-be0b-10ebcfb7c7d3     Kylie Skinner
# 2  82af7481-b7a6-4485-9f24-62f2ee3a70f7  Maricelly Vargas
# 3  25243d7b-d816-4961-b52e-70ec3a916cc6         Lyn Hardy
# 4  32e12a08-d516-431e-86bb-0b488c4fb75f        Holly Hunt
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/AItbvm...
# 1  https://play-lh.googleusercontent.com/a-/AFdZu...
# 2  https://play-lh.googleusercontent.com/a-/AFdZu...
# 3  https://play-lh.googleusercontent.com/a-/AFdZu...
# 4  https://play-lh.googleusercontent.com/a-/AFdZu...
#
#                                              content  score  thumbsUpCount  \
# 0  Facebook sometimes keep telling me that I have...      1            209
# 1  Every other review talking about the reels and...      1          10785
# 2  So, for the first time in over 10 years of me ...      1           2309
# 3  Really poor user controls. Updates the feed af...      1           1897
# 4  It's barely functional anymore. Half the time ...      1            435
#
#   reviewCreatedVersion                  at replyContent repliedAt
# 0       380.0.0.29.109 2022-08-26 06:47:30         None      None
# 1       383.1.0.25.106 2022-09-09 22:41:18         None      None
# 2       383.1.0.25.106 2022-09-13 05:24:11         None      None
# 3       383.1.0.25.106 2022-09-13 09:26:28         None      None
# 4       383.1.0.25.106 2022-09-13 17:14:38         None      None

# %%
len(scrapeddata.index)
# Out:
# 1500

# %%
scrapeddata[['content','score','at']].head()
# Out:
#                                              content  score  \
# 0  Facebook sometimes keep telling me that I have...      1
# 1  Every other review talking about the reels and...      1
# 2  So, for the first time in over 10 years of me ...      1
# 3  Really poor user controls. Updates the feed af...      1
# 4  It's barely functional anymore. Half the time ...      1
#
#                    at
# 0 2022-08-26 06:47:30
# 1 2022-09-09 22:41:18
# 2 2022-09-13 05:24:11
# 3 2022-09-13 09:26:28
# 4 2022-09-13 17:14:38

# %%
scrappeddata1 = scrapeddata[['content','score','at']]
sorteddata = scrappeddata1.sort_values(by='at', ascending=False) #Sort by Newest, change to True if you want to sort by Oldest.
sorteddata.head()
# Out:
#                                                 content  score  \
# 846   here we go AGAIN! day 8 EIGHT ! : congratulati...      1
# 101   For a while I have just hidden ads. Now I am b...      1
# 1343  Well I would have given it a great review exce...      1
# 248   Today the app has completely stopped working. ...      1
# 624   the site offers extra features, while totally ...      2
#
#                       at
# 846  2022-09-14 15:21:33
# 101  2022-09-13 18:46:59
# 1343 2022-09-13 18:42:49
# 248  2022-09-13 18:40:31
# 624  2022-09-13 18:36:22

# %%
sorteddata.to_csv("playstorescrapping.csv", index = False)  #Save the file as CSV , to download: click the folder icon on the left. the csv file should be there.
